# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# -polynomial regression is a regression technique used to model a non-linear relationship b/w an independent variable and a dependent variable
# by expressing the input variable as a polynomial of degree greater than one,
# while still using linear regression to estimate the coefficients.

# %% [markdown]
# #### General Polynomial Regression Equations

# %% [markdown]
# ![Polynomial.jpeg](attachment:f37f64a2-8260-42e3-877f-f15a4120da9e.jpeg)

# %% [markdown]
# ![Polynomial2.jpeg](attachment:67acb02e-fcbc-4229-9838-7323e701c4b9.jpeg)

# %% [markdown]
# ![Polynomial3.jpeg](attachment:0604d400-71bd-46ac-846b-4ebb9a776aa2.jpeg)

# %% [markdown]
# ![Polynomial4.jpeg](attachment:5d56cd1d-d72c-464a-b44a-5baefd6b22fd.jpeg)

# %% [markdown]
# ![Polynomial5.png](attachment:515411ee-df94-4063-96b7-6ea81b0f921c.png)
