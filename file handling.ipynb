# %%
f=open('abc.txt','w')
print("file name:",f.name)
print("file mode:",f.mode)
print(f.readable())
print(f.writable())
f.close()
print(f.closed)
# Out:
# file name: abc.txt
# file mode: w
# False
# True
# True

# %%
with open('abc.txt',"r")as file:
    content=file.read()
print(content)
# Out:
# Yandamuri durga Kaveri

# %%
with open('abc.txt',"r")as file:
    content=file.read(3)
print(content)
# Out:
# Yan

# %%
with open('abc.txt',"r")as file:
    content=file.readline()
print(content)
# Out:
# Yandamuri durga Kaveri

# %%
with open('abc.txt',"r")as file:
    content=file.readlines()
print(content)
# Out:
# ['Yandamuri durga Kaveri']

# %%
with open('abc.txt','w')as file:
    content=file.write("Aditya degree college")

# %%
with open('abc.txt','a')as file:
    content=file.write("Aditya degree college")

# %%
import csv
with open("kav.csv", 'w',newline="")as file:
    k=csv.writer(file)
    k.writerow(["name","age","city"])
    k.writerow(["durga",16,"smk"])

# %%
import csv
with open("kav.csv","r")as file:
    k=csv.reader(file)
    for row in k:
        print(row)
# Out:
# ['name', 'age', 'city']
# ['durga', '16', 'smk']
